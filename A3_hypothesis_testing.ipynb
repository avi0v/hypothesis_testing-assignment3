# %% [markdown]
# #HYPOTHESIS TESTING - assingment 3 using python
# ![hypothesis test using python.PNG](data:image/png;base64,...)

# %%
# LOADING LIBRARY

import pandas as pd  # data manipulation
import numpy as np
import scipy.stats as stats # INFERENTIAL STATS
from google.colab import files

# %% [markdown]
# # case study - CUTLETS
# A F&B manager wants to determine whether there is any significant difference in the diameter of the cutlet between two units.
#
# TEST TYPE - COMPARISION TEST ( 2SAMPLE T-TEST)
#
# SIGNIFICANCE LEVEL (ALPHA) - 5%
#
# DEFINING HYPOTHESIS :
#
# NULL (H0) -**NO difference**  in the diameter of the cutlet between two units
#
# ALTERNATE (H1) -**YES**, there is difference in the diameter of the cutlet between two units

# %%
#loading data
file=files.upload()
# Out:
#      <input type="file" id="files-7b893953-a4ce-4a3c-8a33-02f05fe8437e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b893953-a4ce-4a3c-8a33-02f05fe8437e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cutlets=pd.read_csv("Cutlets.csv")
cutlets.head()
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
#Data pre-processing
cutlets.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %%
#Data anlysis
cutlets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Unit A  35 non-null     float64
#  1   Unit B  35 non-null     float64
# dtypes: float64(2)
# memory usage: 688.0 bytes

# %%
#since no null value hence cont testing

# %%
#2 SAMPLE T-TEST
test=stats.ttest_ind(cutlets["Unit A"],cutlets["Unit B"])
test
# Out:
# Ttest_indResult(statistic=0.7228688704678063, pvalue=0.4722394724599501)

# %%
# t valu and p-value from test result tuple
print("t-value = ",test[0])
print("p-value = ",test[1])
print("----------------------------------------------")
print("since P-value > 0.05 , hence NULL IS SUPPORTED ")
print("----------------------------------------------")
# Out:
# t-value =  0.7228688704678063
# p-value =  0.4722394724599501
# ----------------------------------------------
# since P-value > 0.05 , hence NULL IS SUPPORTED
# ----------------------------------------------

# %% [markdown]
# since p-value > 0.05
#
# Therefore , NULL HYPOTHESIS IS SUPPORTED
#
# CONCLUDING-
#
# 1.There is no significant difference in unit-A and unit-B
#
# 2.and if there any difference , that will arise by chance or random

# %% [markdown]
# #-------------------------2-----------------------------

# %% [markdown]
# # case study - laboratories samples compared
# whether there is any difference in average TAT among the different laboratories
#
# TEST TYPE - COMPARISION TEST (ANOVA) since no 0f group >2
#
# SIGNIFICANCE LEVEL (ALPHA) - 5%
#
# DEFINING HYPOTHESIS :
#
# NULL (H0) -**NO difference**  among the different laboratories
#
# ALTERNATE (H1) -**YES**, there is difference among the different laboratories

# %%
file=files.upload()
# Out:
#      <input type="file" id="files-fccb8360-b8af-4e67-9318-3cf9ff95933d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fccb8360-b8af-4e67-9318-3cf9ff95933d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
labs=pd.read_csv("LabTAT.csv")
labs.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
#data cleaning and info
labs.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
labs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laboratory 1  120 non-null    float64
#  1   Laboratory 2  120 non-null    float64
#  2   Laboratory 3  120 non-null    float64
#  3   Laboratory 4  120 non-null    float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %%
#hence 4 labs data is to be compared , therefore using ANALYSIS OF VARIANCE TEST

# %%
#USING AVONA TEST IN SCIPY STATS
test=stats.f_oneway(labs["Laboratory 1"],labs["Laboratory 2"],labs["Laboratory 3"],labs["Laboratory 4"])

# %%
test
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
#conxlude
print("f-value = ",test[0])
print("p-value = ",test[1])
print("----------------------------------------------")
print("since P-value < 0.05 , hence NULL IS REJECTED ")
print("----------------------------------------------")
# Out:
# f-value =  118.70421654401437
# p-value =  2.1156708949992414e-57
# ----------------------------------------------
# since P-value < 0.05 , hence NULL IS REJECTED
# ----------------------------------------------

# %% [markdown]
# conclusion
#
# since p-value < 0.05
#
# Therefore , ALTERNATIVE HYPOTHESIS IS SUPPORTED
#
#
# CONCLUDING-
#
# 1.There is significant difference in average TAT among the different laboratories
#
# 2.and difference , that arise are not by chance or random

# %% [markdown]
# #------------------------3------------------------

# %% [markdown]
# ## case study - MALE-FEMALE BUYERS RATIO
# Find if male-female buyer rations are similar across regions
#
# TEST TYPE - COMPARISION TEST ( chi-square TEST for independence)
#
# SIGNIFICANCE LEVEL (ALPHA) - 5%
#
# DEFINING HYPOTHESIS :
#
# NULL (H0) - male-female buyer rations are similar across regions
#
# ALTERNATE (H1) -**YES**, there is difference in male-female buyer rations across regions

# %%
#UPLOADING DATA
file=files.upload()
# Out:
#      <input type="file" id="files-b54e11b5-2b85-40e7-ab86-900c3d22f8ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b54e11b5-2b85-40e7-ab86-900c3d22f8ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#loading data
buyers=pd.read_csv("BuyerRatio.csv")
buyers
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %% [markdown]
# ![male female buyers.PNG](data:image/png;base64,...)

# %%
buyer=buyers.iloc[:,1:6]
buyer
# Out:
#    East  West  North  South
# 0    50   142    131     70
# 1   435  1523   1356    750

# %%
#CHI SQUARE TEST
test=stats.chi2_contingency(buyer)

# %%
#results
test
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
print('CHI-VALUE = ',test[0])
print('P-VALUE = ',test[1])
print('---------------------------------------')
print(' since pvalue > 0.05 hence NULL HYPOTESIS SUPPORTED')
print('---------------------------------------')
# Out:
# CHI-VALUE =  1.595945538661058
# P-VALUE =  0.6603094907091882
# ---------------------------------------
#  since pvalue > 0.05 hence NULL HYPOTESIS SUPPORTED
# ---------------------------------------

# %% [markdown]
# since p-value > 0.05
#
# Therefore , NULL HYPOTHESIS IS SUPPORTED
#
# CONCLUDING-
# ** male-female buyer rations are similar across regions**

# %% [markdown]
# #-----------------------------4-----------------------------

# %% [markdown]
# #case study -defective/error free product
#
# The manager wants to check whether the defective %  varies by centre
#
# TEST TYPE - COMPARISION TEST ( CHI SQUARE-TEST)
#
# SIGNIFICANCE LEVEL (ALPHA) - 5%
#
# DEFINING HYPOTHESIS :
#
# NULL (H0) -**NO difference** amoung centre
#
# ALTERNATE (H1) -**YES**, there is difference in the defective % which varies across centre

# %%
#loading data
files=files.upload()
# Out:
#      <input type="file" id="files-9055c13c-320f-4073-9a7e-3620c295395b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9055c13c-320f-4073-9a7e-3620c295395b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#data manipualtion
product=pd.read_csv('Costomer+OrderForm.csv')
product.head()
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free

# %% [markdown]
# ![ORDER DEF ERROR FREE.PNG](data:image/png;base64,...)

# %%
order=product.stack().reset_index()

# %%
order.head()
# Out:
#    level_0       level_1           0
# 0        0  Phillippines  Error Free
# 1        0     Indonesia  Error Free
# 2        0         Malta   Defective
# 3        0         India  Error Free
# 4        1  Phillippines  Error Free

# %%
crosstab=pd.crosstab(order[0],order['level_1'])
crosstab
# Out:
# level_1     India  Indonesia  Malta  Phillippines
# 0
# Defective      20         33     31            29
# Error Free    280        267    269           271

# %%
#NOW CONTINGENCY TABLE IS PREPARED
#USING CHI TEST
chi,p,dof,expected_value=stats.chi2_contingency(crosstab)

# %%
print('chi-value = ',chi)
print('p-value = ', p )
print('-------------------------------------')
print('since p-value > 0.05 hence NULL IS SUPPORTED')
print('-------------------------------------')
# Out:
# chi-value =  3.858960685820355
# p-value =  0.2771020991233135
# -------------------------------------
# since p-value > 0.05 hence NULL IS SUPPORTED
# -------------------------------------

# %% [markdown]
# since p-value > 0.05
#
# Therefore , NULL HYPOTHESIS IS SUPPORTED
#
# CONCLUDING- ** defective % do not varies across centre**
